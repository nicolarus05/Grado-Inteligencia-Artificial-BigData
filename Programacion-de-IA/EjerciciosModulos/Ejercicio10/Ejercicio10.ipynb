# %% [markdown]
# 10) Comprobación de paquetes instalados (pip list + subprocess)
# Escribe un script que muestre todos los paquetes instalados en tu entorno y sus versiones usando:
#
# subprocess para ejecutar pip list del mismo intérprete de Python.

# %%
# Pista:
# import subprocess, sys
# cmd = [sys.executable, "-m", "pip", "list"]
# out = subprocess.check_output(cmd, text=True)
# print(out)

import subprocess, sys

cmd = [sys.executable, "-m", "pip", "list"]
out = subprocess.check_output(cmd, text=True)
print(out)
# Out:
# Package                     Version
# --------------------------- -------------
# appdirs                     1.4.4
# asttokens                   2.4.1
# attrs                       23.2.0
# Automat                     22.10.0
# Babel                       2.10.3
# bcrypt                      3.2.2
# beautifulsoup4              4.12.3
# blinker                     1.7.0
# Brotli                      1.1.0
# bytecode                    0.15.1
# certifi                     2023.11.17
# chardet                     5.2.0
# click                       8.1.6
# cloud-init                  25.1.4
# colorama                    0.4.6
# comm                        0.2.1
# command-not-found           0.3
# configobj                   5.0.8
# constantly                  23.10.4
# contourpy                   1.0.7
# coverage                    7.4.4
# cryptography                41.0.7
# cssselect                   1.2.0
# cycler                      0.11.0
# dbus-python                 1.3.2
# ...
